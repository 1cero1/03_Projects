# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data from file

# %%
df = pd.read_csv("adult_eda.csv")

# %% [markdown]
# # Try to undersstand what the data looks like? What are types of the features? Are there any missing values? Do I need to eliminate some features?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 0   39         State-gov   77516  ...             40   United-States  <=50K
# 1   50  Self-emp-not-inc   83311  ...             13   United-States  <=50K
# 2   38           Private  215646  ...             40   United-States  <=50K
# 3   53           Private  234721  ...             40   United-States  <=50K
# 4   28           Private  338409  ...             40            Cuba  <=50K
#
# [5 rows x 15 columns]

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  ...  32561.000000    32561.000000
# mean      38.581647  1.897784e+05  ...     87.303830       40.437456
# std       13.640433  1.055500e+05  ...    402.960219       12.347429
# min       17.000000  1.228500e+04  ...      0.000000        1.000000
# 25%       28.000000  1.178270e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783560e+05  ...      0.000000       40.000000
# 75%       48.000000  2.370510e+05  ...      0.000000       45.000000
# max       90.000000  1.484705e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Look at the value counts of columns that have object datatype and replace '?' like values with 'Unknown' word.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
#df.describe(include="object").T
df.select_dtypes(include=['object']).describe()
# Out:
#        workclass education      marital-status  ...    sex native-country salary
# count      32561     32561               32561  ...  32561          32561  32561
# unique         9        16                   7  ...      2             42      2
# top      Private   HS-grad  Married-civ-spouse  ...   Male  United-States  <=50K
# freq       22696     10501               14976  ...  21790          29170  24720
#
# [4 rows x 9 columns]

# %%
#look at workclass column here
df["workclass"].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df["workclass"].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
#replace all '?' in whole df with 'Unknown'
# df.loc[df.workclass == "?", "workclass"] = "Unknown"
#df.workclass.replace('?','Unknown', inplace=True)
df.replace(to_replace="?",value="Unknown",inplace=True)

# %%
df
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 0       39         State-gov   77516  ...             40   United-States  <=50K
# 1       50  Self-emp-not-inc   83311  ...             13   United-States  <=50K
# 2       38           Private  215646  ...             40   United-States  <=50K
# 3       53           Private  234721  ...             40   United-States  <=50K
# 4       28           Private  338409  ...             40            Cuba  <=50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 32556   27           Private  257302  ...             38   United-States  <=50K
# 32557   40           Private  154374  ...             40   United-States   >50K
# 32558   58           Private  151910  ...             40   United-States  <=50K
# 32559   22           Private  201490  ...             20   United-States  <=50K
# 32560   52      Self-emp-inc  287927  ...             40   United-States   >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Do education and education_num columns hold similar information? If so drop the appropriate choice between them.

# %%
df["education"]
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
#             ...
# 32556    Assoc-acdm
# 32557       HS-grad
# 32558       HS-grad
# 32559       HS-grad
# 32560       HS-grad
# Name: education, Length: 32561, dtype: object

# %%
df["education-num"]
# Out:
# 0        13.0
# 1        13.0
# 2         9.0
# 3         7.0
# 4        13.0
#          ...
# 32556    12.0
# 32557     9.0
# 32558     9.0
# 32559     9.0
# 32560     9.0
# Name: education-num, Length: 32561, dtype: float64

# %%
df.groupby("education")["education-num"].value_counts()
# Out:
# education     education-num
# 10th          6.0                916
# 11th          7.0               1146
# 12th          8.0                424
# 1st-4th       2.0                161
# 5th-6th       3.0                330
# 7th-8th       4.0                631
# 9th           5.0                503
# Assoc-acdm    12.0              1044
# Assoc-voc     11.0              1343
# Bachelors     13.0              5247
# Doctorate     16.0               405
# HS-grad       9.0              10215
# Masters       14.0              1687
# Preschool     1.0                 50
# Prof-school   15.0               559
# Some-college  10.0              7098
# Name: education-num, dtype: int64

# %%
df["education-num"].value_counts()
# Out:
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: education-num, dtype: int64

# %%
#drop one of them here
df.drop(columns="education-num",axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Take a look at correlation between variables and also see if there are some outliers in any of the columns.

# %%
df.corr()
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076646      0.077674      0.057775        0.068756
# fnlwgt         -0.076646  1.000000      0.000432     -0.010252       -0.018768
# capital-gain    0.077674  0.000432      1.000000     -0.031615        0.078409
# capital-loss    0.057775 -0.010252     -0.031615      1.000000        0.054256
# hours-per-week  0.068756 -0.018768      0.078409      0.054256        1.000000

# %%
df.describe()
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  32561.000000  32561.000000    32561.000000
# mean      38.581647  1.897784e+05   1077.648844     87.303830       40.437456
# std       13.640433  1.055500e+05   7385.292085    402.960219       12.347429
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.178270e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.783560e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.370510e+05      0.000000      0.000000       45.000000
# max       90.000000  1.484705e+06  99999.000000   4356.000000       99.000000

# %%
#age column
Q1=df.age.quantile(0.25)
Q3=df.age.quantile(0.75)
IQR = Q3-Q1

# %%
upper_lim_age= Q3+ IQR*1.5
upper_lim_age
# Out:
# 78.0

# %%
df[df["age"] >= upper_lim_age]["age"].value_counts()
# Out:
# 90    43
# 78    23
# 79    22
# 80    22
# 81    20
# 82    12
# 84    10
# 83     6
# 88     3
# 85     3
# 86     1
# 87     1
# Name: age, dtype: int64

# %%
fig ,ax = plt.subplots(2,3,figsize=(20,7))
x = 0
y = 0
for column in df.select_dtypes('number').columns:
    
    df[column].plot(kind = "box", ax = ax[x,y])
    if y < 2:
        y += 1
    else:
        x += 1
        y = 0

# %%
df[(df["hours-per-week"] == 99)].sample(10)
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 12788   24         State-gov  208826  ...             99        England  <=50K
# 4441    43      Self-emp-inc  286750  ...             99  United-States   >50K
# 20036   61      Self-emp-inc  102191  ...             99  United-States  <=50K
# 10266   56      Self-emp-inc  184598  ...             99  United-States  <=50K
# 23830   45  Self-emp-not-inc  106110  ...             99  United-States  <=50K
# 25713   32           Private  183304  ...             99  United-States   >50K
# 15460   37           Private  241174  ...             99  United-States   >50K
# 31699   43  Self-emp-not-inc  163108  ...             99  United-States  <=50K
# 21147   39           Private  348521  ...             99  United-States   >50K
# 10143   35           Unknown  164866  ...             99  United-States  <=50K
#
# [10 rows x 14 columns]

# %%
#hours per week column
Q1=df["hours-per-week"].quantile(0.25)
Q3=df["hours-per-week"].quantile(0.75)
IQR = Q3-Q1

# %%
upper_lim_week= Q3+1.5*IQR
upper_lim_week
# Out:
# 52.5

# %%
# find outlier values which extends the upper limit in both age and hours-per-week columns

# %%
outliers= df[(df["hours-per-week"]>upper_lim_week) & (df["age"]>upper_lim_age)]
outliers
# Out:
#        age     workclass  fnlwgt  ... hours-per-week native-country salary
# 3777    80       Private   87518  ...             60  United-States  <=50K
# 5370    90     Local-gov  227796  ...             60  United-States   >50K
# 7481    83       Private  195507  ...             55  United-States  <=50K
# 7720    84       Private  241065  ...             66  United-States  <=50K
# 8806    90       Private   87372  ...             72  United-States   >50K
# 11996   90       Private   40388  ...             55  United-States  <=50K
# 12830   81       Private  201398  ...             60        Unknown  <=50K
# 15356   90       Private   90523  ...             99  United-States  <=50K
# 24395   83  Self-emp-inc  153183  ...             55  United-States   >50K
#
# [9 rows x 14 columns]

# %% [markdown]
# # After looking at the outliers you can drop the rows which actually does not make any sense.
# ** Hint: You can check age and hours per week columns. **

# %%
drop_index=df.loc[(df["hours-per-week"]>upper_lim_week) & (df["age"]>upper_lim_age)].index
df.drop(drop_index,inplace=True)

# %%
df[(df["hours-per-week"]>upper_lim_week) & (df["age"]>upper_lim_age)].sort_values(by=["age","hours-per-week"])
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
# check outlier values which extends the upper limit in both age and hours-per-week columns
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %% [markdown]
# # Impute missing values in relationship column with 'Unmarried'. Also replace 'Not-in-family','Other-relative' values in this column with 'Unmarried'?

# %%
df.relationship.value_counts()
# Out:
# Husband           13190
# Not-in-family      8301
# Unmarried          3444
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df.fillna("Unmarried",inplace=True)

# %%
df.replace(to_replace=["Not-in-family","Other-relative"],value="Unmarried",inplace=True)

# %%
df.relationship.value_counts()
# Out:
# Unmarried    17794
# Husband      13190
# Wife          1568
# Name: relationship, dtype: int64

# %% [markdown]
# ---
# # How many of each race are represented in this dataset?
# ---

# %%
race_count = df.race.value_counts()
race_count
# Out:
# White                 27807
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
race_count.sort_values().plot.barh();

# %% [markdown]
# ---
# # What is the average age of men/women?
# ---

# %%
#df.groupby(by='sex')['age'].mean()

# %%
average_age_men =df.groupby(by='sex')['age'].mean()["Male"]
average_age_men
# Out:
# 39.41444378127726

# %%
round(average_age_men,1)
# Out:
# 39.4

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Male", "age"].value_counts().plot.bar();

# %%
average_age_women = df.groupby(by='sex')['age'].mean()["Female"]
average_age_women
# Out:
# 36.85823043357163

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Female", "age"].value_counts().plot.bar();

# %% [markdown]
# ---
# # What is the percentage of people who have a Bachelor's degree?
# ---

# %%
print("education")
df.education.value_counts().sort_index()
# Out:
# education
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           646
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5353
# Doctorate         413
# HS-grad         10499
# Masters          1720
# Preschool          51
# Prof-school       575
# Some-college     7290
# Name: education, dtype: int64

# %%
df["education"].value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
upper=len(df[df["education"]=="Bachelors"])

lower=df.education.value_counts().sum()

percentage_bachelors = upper / lower * 100

percentage_bachelors
# Out:
# 16.44445809781273

# %%
df["education"].value_counts(normalize=True)
# Out:
# HS-grad         0.322530
# Some-college    0.223949
# Bachelors       0.164445
# Masters         0.052839
# Assoc-voc       0.042455
# 11th            0.036096
# Assoc-acdm      0.032778
# 10th            0.028662
# 7th-8th         0.019845
# Prof-school     0.017664
# 9th             0.015790
# 12th            0.013302
# Doctorate       0.012687
# 5th-6th         0.010230
# 1st-4th         0.005161
# Preschool       0.001567
# Name: education, dtype: float64

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc["Bachelors"]*100
round(percentage_bachelors,1)
# Out:
# 16.4

# %%
print(f"The percentage of people who have a Bachelor's degree : %{round(percentage_bachelors,1)}")
# Out:
# The percentage of people who have a Bachelor's degree : %16.4

# %% [markdown]
# ---
# # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# ---

# %%
#df["salary"].loc[(df.salary=="<=50K") | (df.salary==">50K")].value_counts()
df["salary"].value_counts()
# Out:
# <=50K    24714
# >50K      7838
# Name: salary, dtype: int64

# %%
df["education"].value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
higher_education = df["education"].isin(["Bachelors", "Masters", "Doctorate"]).sort_index()
higher_education
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32552, dtype: bool

# %%
df_high_edu = df[df["education"].isin(["Bachelors", "Masters","Doctorate"])].sort_index()
df_high_edu
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 0       39         State-gov   77516  ...             40  United-States  <=50K
# 1       50  Self-emp-not-inc   83311  ...             13  United-States  <=50K
# 4       28           Private  338409  ...             40           Cuba  <=50K
# 5       37           Private  284582  ...             40  United-States  <=50K
# 8       31           Private   45781  ...             50  United-States   >50K
# ...    ...               ...     ...  ...            ...            ...    ...
# 32538   38           Private  139180  ...             45  United-States   >50K
# 32539   71           Unknown  287372  ...             10  United-States   >50K
# 32544   31           Private  199655  ...             30  United-States  <=50K
# 32553   32           Private  116138  ...             11         Taiwan  <=50K
# 32554   53           Private  321865  ...             40  United-States   >50K
#
# [7486 rows x 14 columns]

# %%
df[(df["education"].isin(["Bachelors", "Masters","Doctorate"])) &  (df.salary==">50K")].sort_index()
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 8       31           Private   45781  ...             50  United-States   >50K
# 9       42           Private  159449  ...             40  United-States   >50K
# 11      30         State-gov  141297  ...             40          India   >50K
# 19      43  Self-emp-not-inc  292175  ...             45  United-States   >50K
# 20      40           Private  193524  ...             60  United-States   >50K
# ...    ...               ...     ...  ...            ...            ...    ...
# 32533   54           Private  337992  ...             50          Japan   >50K
# 32536   34           Private  160216  ...             55  United-States   >50K
# 32538   38           Private  139180  ...             45  United-States   >50K
# 32539   71           Unknown  287372  ...             10  United-States   >50K
# 32554   53           Private  321865  ...             40  United-States   >50K
#
# [3484 rows x 14 columns]

# %%
count =len(df_high_edu[df_high_edu.salary==">50K"])

# %%
perc_high_edu = count/len(df)

# %%
perc_high_edu
# Out:
# 0.10702875399361023

# %%
print(f"Percentage of people with advanced education make more than 50K : {round(perc_high_edu * 100, 2)}")
# Out:
# Percentage of people with advanced education make more than 50K : 10.7

# %% [markdown]
# ---
# # What percentage of people without advanced education make more than 50K?
# ---

# %%
lower_education= ~df["education"].isin(["Bachelors", "Masters","Doctorate"])

# %%
df_low_edu = df[~df["education"].isin(["Bachelors", "Masters","Doctorate"])].sort_index()
df_low_edu
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 2       38           Private  215646  ...             40  United-States  <=50K
# 3       53           Private  234721  ...             40  United-States  <=50K
# 6       49           Private  160187  ...             16        Jamaica  <=50K
# 7       52  Self-emp-not-inc  209642  ...             45  United-States   >50K
# 10      37           Private  280464  ...             80  United-States   >50K
# ...    ...               ...     ...  ...            ...            ...    ...
# 32556   27           Private  257302  ...             38  United-States  <=50K
# 32557   40           Private  154374  ...             40  United-States   >50K
# 32558   58           Private  151910  ...             40  United-States  <=50K
# 32559   22           Private  201490  ...             20  United-States  <=50K
# 32560   52      Self-emp-inc  287927  ...             40  United-States   >50K
#
# [25066 rows x 14 columns]

# %%
df[(~df["education"].isin(["Bachelors", "Masters","Doctorate"])) &  (df.salary==">50K")].sort_index()
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 7       52  Self-emp-not-inc  209642  ...             45  United-States   >50K
# 10      37           Private  280464  ...             80  United-States   >50K
# 14      40           Private  121772  ...             40        Unknown   >50K
# 27      54           Unknown  180211  ...             60          South   >50K
# 38      31           Private   84154  ...             38        Unknown   >50K
# ...    ...               ...     ...  ...            ...            ...    ...
# 32518   57         Local-gov  110417  ...             40  United-States   >50K
# 32519   46           Private  364548  ...             48  United-States   >50K
# 32545   39         Local-gov  111499  ...             20  United-States   >50K
# 32557   40           Private  154374  ...             40  United-States   >50K
# 32560   52      Self-emp-inc  287927  ...             40  United-States   >50K
#
# [4354 rows x 14 columns]

# %%
count =count =len(df_low_edu[df_low_edu.salary==">50K"])

# %%
count
# Out:
# 4354

# %%
perc_low_edu = count/len(df)

# %%
print(f"Percentage of people without advanced education make more than 50K : {round(perc_low_edu * 100 ,2)}")
# Out:
# Percentage of people without advanced education make more than 50K : 13.38

# %%
if perc_high_edu > perc_low_edu :
    print("More education more money!")
else:
    print("Education has no clear effet on salary. You should investigate some other features also.")
# Out:
# Education has no clear effet on salary. You should investigate some other features also.

# %% [markdown]
# ---
# # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
# ---

# %%
df["hours-per-week"].value_counts()
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1472
# 35     1297
#       ...
# 82        1
# 92        1
# 87        1
# 74        1
# 94        1
# Name: hours-per-week, Length: 94, dtype: int64

# %%
#(df['hours-per-week']==df['hours-per-week'].min()) & (df.salary=='>50K')
lazy_riches = (df["hours-per-week"]== "1" )  & (df.salary == ">50K")
lazy_riches
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32552, dtype: bool

# %%
#df[lazy_riches]
#df[(df["hours-per-week"]== 1) & (df["salary"]== ">50K")]
# Out:
#        age  workclass  fnlwgt  ... hours-per-week native-country salary
# 189     58  State-gov  109567  ...              1  United-States   >50K
# 20072   65    Unknown   76043  ...              1  United-States   >50K
#
# [2 rows x 14 columns]

# %%
#df[lazy_riches].shape[0]
num_lazy_riches = df[(df["hours-per-week"]== 1) & (df["salary"]== ">50K")].value_counts().sum()
num_lazy_riches
# Out:
# 2

# %%
#len(df[df['hours-per-week']==df['hours-per-week'].min()])
num_min_workers = (df["hours-per-week"]== 1).sort_index().sum()
num_min_workers
# Out:
# 20

# %%
print (f"Percentage of the people who work the minimum number of hours per week have a salary of >50K : % {round(num_lazy_riches/num_min_workers*100)}")
# Out:
# Percentage of the people who work the minimum number of hours per week have a salary of >50K : % 10

# %% [markdown]
#  ---
#  # What country has the highest percentage of people that earn >50K?
#  ---

# %%
country_salary_df =df.groupby("native-country")[["salary"]].count()
country_salary_df
# Out:
#                             salary
# native-country
# Cambodia                        19
# Canada                         121
# China                           75
# Columbia                        59
# Cuba                            95
# Dominican-Republic              70
# Ecuador                         28
# El-Salvador                    106
# England                         90
# France                          29
# Germany                        137
# Greece                          29
# Guatemala                       64
# Haiti                           44
# Holand-Netherlands               1
# Honduras                        13
# Hong                            20
# Hungary                         13
# India                          100
# Iran                            43
# Ireland                         24
# Italy                           73
# Jamaica                         81
# Japan                           62
# Laos                            18
# Mexico                         643
# Nicaragua                       34
# Outlying-US(Guam-USVI-etc)      14
# Peru                            31
# Philippines                    198
# Poland                          60
# Portugal                        37
# Puerto-Rico                    114
# Scotland                        12
# South                           80
# Taiwan                          51
# Thailand                        18
# Trinadad&Tobago                 19
# United-States                29162
# Unknown                        582
# Vietnam                         67
# Yugoslavia                      16

# %%
country_salary_df_riches = df[df.salary=='>50K'].groupby("native-country")[["salary"]].count()
country_salary_df_riches
# Out:
#                     salary
# native-country
# Cambodia                 7
# Canada                  39
# China                   20
# Columbia                 2
# Cuba                    25
# Dominican-Republic       2
# Ecuador                  4
# El-Salvador              9
# England                 30
# France                  12
# Germany                 44
# Greece                   8
# Guatemala                3
# Haiti                    4
# Honduras                 1
# Hong                     6
# Hungary                  3
# India                   40
# Iran                    18
# Ireland                  5
# Italy                   25
# Jamaica                 10
# Japan                   24
# Laos                     2
# Mexico                  33
# Nicaragua                2
# Peru                     2
# Philippines             61
# Poland                  12
# Portugal                 4
# Puerto-Rico             12
# Scotland                 3
# South                   16
# Taiwan                  20
# Thailand                 3
# Trinadad&Tobago          2
# United-States         7168
# Unknown                146
# Vietnam                  5
# Yugoslavia               6

# %%
#(country_salary_df_riches/country_salary_df).sort_values('salary',ascending=False)
rich_per_country =df[df.salary=='>50K'].groupby("native-country")[["salary"]].count()/ df.groupby("native-country")[["salary"]].count()
rich_per_country.sort_values(by=['salary'])
# Out:
#                               salary
# native-country
# Dominican-Republic          0.028571
# Columbia                    0.033898
# Guatemala                   0.046875
# Mexico                      0.051322
# Nicaragua                   0.058824
# Peru                        0.064516
# Vietnam                     0.074627
# Honduras                    0.076923
# El-Salvador                 0.084906
# Haiti                       0.090909
# Trinadad&Tobago             0.105263
# Puerto-Rico                 0.105263
# Portugal                    0.108108
# Laos                        0.111111
# Jamaica                     0.123457
# Ecuador                     0.142857
# Thailand                    0.166667
# Poland                      0.200000
# South                       0.200000
# Ireland                     0.208333
# Hungary                     0.230769
# United-States               0.245799
# Scotland                    0.250000
# Unknown                     0.250859
# Cuba                        0.263158
# China                       0.266667
# Greece                      0.275862
# Hong                        0.300000
# Philippines                 0.308081
# Germany                     0.321168
# Canada                      0.322314
# England                     0.333333
# Italy                       0.342466
# Cambodia                    0.368421
# Yugoslavia                  0.375000
# Japan                       0.387097
# Taiwan                      0.392157
# India                       0.400000
# France                      0.413793
# Iran                        0.418605
# Holand-Netherlands               NaN
# Outlying-US(Guam-USVI-etc)       NaN

# %%
rich_per_country[rich_per_country.salary==rich_per_country.salary.max()]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
#use iloc here
#rich_per_country.loc[[rich_per_country.salary.idxmax()]]
rich_per_country.iloc[[0]]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
plt.figure(figsize=(14,7))
df.loc[df["salary"] == ">50K", "native-country"].value_counts().plot(kind="bar");

# %%
plt.figure(figsize=(12,6))
df.loc[((df["native-country"] == "Iran")), "salary"].value_counts().plot.bar();

# %% [markdown]
# ---
# # Identify the most popular occupation for those who earn >50K in India.
# ---

# %%
top_IN_occupation =(df["native-country"]== "India") & (df["salary"] == ">50K")
# df.loc[(df["native-country"]== "India") & (df["salary"] == ">50K")] the second with loc

top_IN_occupation
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32552, dtype: bool

# %%
df[top_IN_occupation]
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 11      30         State-gov  141297  ...             40          India   >50K
# 968     48           Private  164966  ...             40          India   >50K
# 1327    52           Private  168381  ...             40          India   >50K
# 7258    42         State-gov  102343  ...             72          India   >50K
# 7285    54         State-gov   93449  ...             40          India   >50K
# 8124    36           Private  172104  ...             40          India   >50K
# 9939    43       Federal-gov  325706  ...             50          India   >50K
# 10590   35           Private   98283  ...             40          India   >50K
# 10661   59           Private  122283  ...             40          India   >50K
# 10736   30           Private  243190  ...             20          India   >50K
# 11260   54           Private  225599  ...             40          India   >50K
# 11384   34           Private   98283  ...             40          India   >50K
# 13422   53           Private  366957  ...             50          India   >50K
# 13551   40           Private  220977  ...             40          India   >50K
# 13862   45           Private  209912  ...             40          India   >50K
# 16017   41           Private  207578  ...             50          India   >50K
# 16778   43           Private  242968  ...             40          India   >50K
# 16923   41           Private  143003  ...             60          India   >50K
# 17259   57      Self-emp-inc  123053  ...             50          India   >50K
# 17834   29  Self-emp-not-inc  341672  ...             50          India   >50K
# 20417   42      Self-emp-inc   23510  ...             60          India   >50K
# 20465   39           Private  198654  ...             67          India   >50K
# 21128   30           Private  122889  ...             50          India   >50K
# 23474   55         State-gov  120781  ...             40          India   >50K
# 24154   46           Private  229737  ...             50          India   >50K
# 25739   35      Self-emp-inc   79586  ...             40          India   >50K
# 26305   27           Private  207352  ...             40          India   >50K
# 26356   34           Private   99872  ...             40          India   >50K
# 27670   61           Private   80896  ...             45          India   >50K
# 28264   51  Self-emp-not-inc  120781  ...             70          India   >50K
# 28433   42           Private  198341  ...             55          India   >50K
# 28452   53           Private   70387  ...             40          India   >50K
# 28557   34           Private  165737  ...             43          India   >50K
# 28651   45  Self-emp-not-inc  216402  ...             50          India   >50K
# 28798   30  Self-emp-not-inc  116666  ...             50          India   >50K
# 30111   41       Federal-gov  219155  ...             50          India   >50K
# 30152   48           Private  119471  ...             40          India   >50K
# 30833   25           Private  110978  ...             37          India   >50K
# 31327   38         State-gov  125499  ...             60          India   >50K
# 31357   23           Private  143003  ...             50          India   >50K
#
# [40 rows x 14 columns]

# %%
df.loc[(df["native-country"]== "India") & (df["salary"] == ">50K")]["occupation"].value_counts()
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Transport-moving     1
# Sales                1
# Adm-clerical         1
# Name: occupation, dtype: int64

# %%
df[top_IN_occupation]['occupation'].value_counts().index[0]
# Out:
# 'Prof-specialty'

# %%
a =  df[top_IN_occupation]["occupation"].mode()[0]
a
  #use mode here
# Out:
# 'Prof-specialty'

# %%
print(f"{a} the most popular occupation for those who earn >50K in India.")
# Out:
# Prof-specialty the most popular occupation for those who earn >50K in India.

# %% [markdown]
# ----
# ---
